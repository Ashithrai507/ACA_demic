# %%
# !pip install datasets
# Out:
# ...
#   Using cached datasets-4.8.4-py3-none-any.whl.metadata (19 kB)
# ...
#   Using cached filelock-3.29.0-py3-none-any.whl.metadata (2.0 kB)
# ...
#   Using cached numpy-2.4.4-cp314-cp314-macosx_14_0_arm64.whl.metadata (6.6 kB)
# ...
#   Using cached pyarrow-24.0.0-cp314-cp314-macosx_12_0_arm64.whl.metadata (3.0 kB)
# ...
#   Using cached dill-0.4.1-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached pandas-3.0.2-cp314-cp314-macosx_11_0_arm64.whl.metadata (79 kB)
# ...
#   Using cached requests-2.33.1-py3-none-any.whl.metadata (4.8 kB)
# ...
#   Using cached httpx-0.28.1-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached xxhash-3.7.0-cp314-cp314-macosx_11_0_arm64.whl.metadata (13 kB)
# ...
#   Using cached multiprocess-0.70.19-py314-none-any.whl.metadata (7.2 kB)
# ...
#   Using cached fsspec-2026.2.0-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached huggingface_hub-1.12.0-py3-none-any.whl.metadata (14 kB)
# ...
#   Using cached pyyaml-6.0.3-cp314-cp314-macosx_11_0_arm64.whl.metadata (2.4 kB)
# ...

# %%
from datasets import load_dataset
from transformers import AutoTokenizer, AutoModelForSeq2SeqLM

ds = load_dataset("cfilt/iitb-english-hindi", split="validation[:5]")

tok = AutoTokenizer.from_pretrained("Helsinki-NLP/opus-mt-en-hi")
model = AutoModelForSeq2SeqLM.from_pretrained("Helsinki-NLP/opus-mt-en-hi")

text = ds[2]['translation']['en']
print("Input:", text)

inp = tok(text, return_tensors="pt", truncation=True)
out = model.generate(**inp)

print("Output:", tok.decode(out[0], skip_special_tokens=True))
# Out:
# ...
# Generating test split: 100%|██████████| 2507/2507 [00:00<00:00, 750597.48 examples/s]
# /Users/ashithrai/Documents/acad/NLP_lab/.venv/lib/python3.14/site-packages/transformers/models/marian/tokenization_marian.py:176: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# Loading weights: 100%|██████████| 258/258 [00:00<00:00, 55647.97it/s]
# Input: Rajesh Gavre, the President of the MNPA teachers association, honoured the school by presenting the award.
# Output: एमएनएपी शिक्षकों के राष्ट्रपति, राजस्वीवर ने इस पुरस्कार को पेश करने के द्वारा स्कूल की प्रतिष्ठा की.
